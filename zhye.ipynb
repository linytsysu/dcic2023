# %%
import numpy as np
import pandas as pd

# %%
account_static = pd.read_csv('./data/账户静态信息.csv')
account_trade = pd.read_csv('./data/账户交易信息.csv')
y_train = pd.read_csv('./data/训练集标签.csv')
y_test = pd.read_csv('./data/test_dataset.csv')

# %%
y_train.tail(20)
# Out:
#                   zhdh  black_flag
# 1180  CFDF0256D0ADD839           0
# 1181  092452616CE0D9EE           0
# 1182  11D2C8E25DEF815C           0
# 1183  B8CDAE0DE5125363           0
# 1184  14453FA9014D7713           0
# 1185  BD6923450D9B19EB           0
# 1186  4C7F6935BD74A8E1           1
# 1187  030BA1DD9CA8589E           0
# 1188  C643585179C7E98F           0
# 1189  F97ADD7EB54EC0C2           1
# 1190  5051454AB4406881           1
# 1191  F6CC9188EDCE99F8           1
# 1192  C006ED3C770F1218           1
# 1193  ABDA7DBC9EB17D26           1
# 1194  BCF54C7AD7F1FD63           0
# 1195  DF6B4ABA9EB3D2FA           1
# 1196  D3D68EBABD47D4AB           1
# 1197  E9652241DC476711           0
# 1198  5AD34DD10DEE0C9A           1
# 1199  C3E1718849F44BB2           0

# %%
account_trade
# Out:
#                                   jylsxh              zhdh              dfzh  \
# 0       5D252156AE9F6B6595A1C56F56D4F91C  86C379D938234BAA  14BEFED1370B730A
# 1       8BB3D82CA8E5F95577CA3E2DF432DF64  8EB373F073727157  FD7F11B33576339B
# 2       412B7E903BC06882EEB9FB6A484D0773  997DED969A377D40  014F2782648E7FDA
# 3       F1122F893AC75DC8751190C67E1C3DB6  8EB373F073727157  129FAF9FD9D03346
# 4       8BD9575EA55E67D4E99AC43B2A444172  8EB373F073727157  3B9CD92F13274EBA
# ...                                  ...               ...               ...
# 816265  A667838479DE22ADA9FB23C2D51C84CF  F2FC33BA63FC3527  5723E6A89A2013FE
# 816266  6070ADCB67DA922E11ACE01E96591D51  C74582847470D39C  9D0B34E9E20538C2
# 816267  3FBA77BB98D5459B90214711D02B1273  0F574B919C0A5D0F  14BEFED1370B730A
# 816268  F829B858E2852F1BE08AD68DA0894932  F2FC33BA63FC3527  37B25962B1AD8CB8
# 816269  97DDF4F9839780AFFF08B7E8C61B3399  07F1FCCE0F228051  4DD78576A1B59702
#
#         jdbj     jyje      zhye      dfhh        jyrq      jysj      jyqd  \
# 0          0   310.00  57806.83  834E1F06  2020-03-01  00:18:06  E96ED478
# 1          1   599.99   7099.73  B3D461D4  2020-03-01  00:18:17  621461AF
# 2          1  4000.00  34448.04  A71C76B8  2020-03-01  00:18:30  621461AF
# 3          1   299.98   7399.71  8A1BC467  2020-03-01  00:19:06  621461AF
# 4          1   999.96   8399.67  A8DA3378  2020-03-01  00:19:17  091D584F
# ...      ...      ...       ...       ...         ...       ...       ...
# 816265     1  1000.00   1002.07  2BE0C959  2020-05-31  23:57:17  621461AF
# 816266     0  5000.00     46.58  B3D461D4  2020-05-31  23:58:21  091D584F
# 816267     0    18.90   1083.77  834E1F06  2020-05-31  23:59:30  E96ED478
# 816268     0   681.70    320.37  469F7281  2020-05-31  23:59:38  E96ED478
# 816269     0     1.00   2877.83  2BE0C959  2020-05-31  23:59:44  091D584F
#
#             zydh  dfmccd
# 0       4E0CB6FB      45
# 1       A3C65C29       6
# 2       A3C65C29       6
# 3       A3C65C29       6
# 4       2618045A       6
# ...          ...     ...
# 816265  A3C65C29       6
# 816266  A97DA629       6
# 816267  4E0CB6FB      45
# 816268  4E0CB6FB       9
# 816269  A97DA629       9
#
# [816270 rows x 12 columns]

# %%
account_trade[account_trade['zhdh'] == 'CFDF0256D0ADD839'].reset_index(drop=True)['zhye'].plot()
# Out:
# <AxesSubplot:>
